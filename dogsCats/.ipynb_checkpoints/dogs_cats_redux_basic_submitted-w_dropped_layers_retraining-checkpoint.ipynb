# %% [markdown]
# # Dogs vs Cat Redux

# %% [markdown]
# In this tutorial, you will learn how generate and submit predictions to a Kaggle competiton
#
# [Dogs vs. Cats Redux: Kernels Edition](https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition)

# %% [markdown]
# To start you will need to download and unzip the competition data from Kaggle and ensure your directory structure looks like this
# ```
# utils/
#     vgg16.py
#     utils.py
# lesson1/
#     redux.ipynb
#     data/
#         redux/
#             train/
#                 cat.437.jpg
#                 dog.9924.jpg
#                 cat.1029.jpg
#                 dog.4374.jpg
#             test/
#                 231.jpg
#                 325.jpg
#                 1235.jpg
#                 9923.jpg
# ```
#
# You can download the data files from the competition page [here](https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition/data) or you can download them from the command line using the [Kaggle CLI](https://github.com/floydwch/kaggle-cli).
#
# You should launch your notebook inside the lesson1 directory
# ```
# cd lesson1
# jupyter notebook
# ```

# %%
from datetime import datetime

# %%
# %cd /home/ubuntu/fastai/data/dogscats/
# %kg download -u 'username' -p 'password' -c 'dogs-vs-cats-redux-kernels-edition'
# %unzip test.zip
# %unzip train.zip

# %%
#Verify we are in the lesson1 directory
# %pwd
# Out:
# u'/home/ubuntu/fastai/fastai_bmt_reworking/dogsCats'

# %%
#Create references to important directories we will use over and over
import os, sys
current_dir = os.getcwd()
LESSON_HOME_DIR = current_dir
#DATA_HOME_DIR = current_dir+'/data/redux'

# %%
#Allow relative imports to directories above lesson1/
sys.path.insert(1, os.path.join(sys.path[0], '..'))

# %%
HOMEPATH = "/home/ubuntu/fastai/"
DATA_HOME_DIR = HOMEPATH + "data/dogscats/"

# %%
os.chdir(HOMEPATH)
print ("os.getcwd:", os.getcwd())
#import modules
from utils import *
from vgg16 import Vgg16

#Instantiate plotting tool
#In Jupyter notebooks, you will need to run this command before doing any plotting
# %matplotlib inline
# Out:
# ('os.getcwd:', '/home/ubuntu/fastai')
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5110)
# Using TensorFlow backend.

# %% [markdown]
# ## Action Plan
# 1. Create Validation and Sample sets
# 2. Rearrange image files into their respective directories
# 3. Finetune and Train model
# 4. Generate predictions
# 5. Validate predictions
# 6. Submit predictions to Kaggle

# %% [markdown]
# ## Create validation set and sample

# %%
print (DATA_HOME_DIR)
# %ls $DATA_HOME_DIR
# Out:
# /home/ubuntu/fastai/data/dogscats/
# sample_submission.csv  test/  test.zip  train/  train.zip

# %%
#Create directories
# %cd $DATA_HOME_DIR
# %mkdir valid
# %mkdir results
# %mkdir -p sample/train
# %mkdir -p sample/test
# %mkdir -p sample/valid
# %mkdir -p sample/results
# %mkdir -p test/unknown
# Out:
# /home/ubuntu/fastai/data/dogscats

# %%
print (DATA_HOME_DIR)
# %ls $DATA_HOME_DIR
# Out:
# /home/ubuntu/fastai/data/dogscats/
# results/  sample_submission.csv  test.zip  train.zip
# sample/   test/                  train/    valid/

# %%
# %cd $DATA_HOME_DIR/train
# Out:
# /home/ubuntu/fastai/data/dogscats/train

# %%
print (DATA_HOME_DIR+'valid/')
# %find /home/ubuntu/fastai/data/dogscats/valid/. -type f | wc -l
# Out:
# /home/ubuntu/fastai/data/dogscats/valid/

# %%
g = glob('*.jpg')
shuf = np.random.permutation(g)
for i in range(2000): os.rename(shuf[i], DATA_HOME_DIR+'valid/' + shuf[i])

# %%
#after above block, should be 2000 files in valid

DIR = '/home/ubuntu/fastai/data/dogscats/valid/'
print len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
# Out:
# 2000

# %%
from shutil import copyfile

# %%
print (os.getcwd())
# Out:
# /home/ubuntu/fastai/data/dogscats/train

# %%
print (DATA_HOME_DIR+'sample/train/')
DIR = DATA_HOME_DIR+'sample/train/'
print len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
# Out:
# /home/ubuntu/fastai/data/dogscats/sample/train/
# 200

# %%
g = glob('*.jpg')
shuf = np.random.permutation(g)
for i in range(200): copyfile(shuf[i], DATA_HOME_DIR+'sample/train/' + shuf[i])

# %%
DIR = DATA_HOME_DIR+'sample/train/'
print len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
# Out:
# 200

# %%
# %cd $DATA_HOME_DIR/valid
# Out:
# /home/ubuntu/fastai/data/dogscats/valid

# %%
DIR = DATA_HOME_DIR+'sample/valid/'
print len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
# Out:
# 0

# %%
g = glob('*.jpg')
shuf = np.random.permutation(g)
for i in range(50): copyfile(shuf[i], DATA_HOME_DIR+'/sample/valid/' + shuf[i])

# %%
DIR = DATA_HOME_DIR+'sample/valid/'
print len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
# Out:
# 50

# %% [markdown]
# ## Rearrange image files into their respective directories

# %%
DATA_HOME_DIR
# Out:
# '/home/ubuntu/fastai/data/dogscats/'

# %%
#Divide cat/dog images into separate directories
DIR = DATA_HOME_DIR+'valid/'
print "before move: # files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])

# %cd $DATA_HOME_DIR/valid
# %mkdir cats
# %mkdir dogs
# %mv cat.*.jpg cats/
# %mv dog.*.jpg dogs/
#when done there should be zero files left in train 
DIR = DATA_HOME_DIR+'valid/'
print "after move: # files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
DIR = DATA_HOME_DIR+'valid/cats/'
print "# files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
DIR = DATA_HOME_DIR+'valid/dogs/'
print "# files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
# Out:
# before move: # files in  /home/ubuntu/fastai/data/dogscats/valid/ 2000
# /home/ubuntu/fastai/data/dogscats/valid
# after move: # files in  /home/ubuntu/fastai/data/dogscats/valid/ 0
# # files in  /home/ubuntu/fastai/data/dogscats/valid/cats/ 976
# # files in  /home/ubuntu/fastai/data/dogscats/valid/dogs/ 1024

# %%
#Divide cat/dog images into separate directories
DIR = DATA_HOME_DIR+'sample/train/'
print "before move: # files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])

# %cd $DATA_HOME_DIR/sample/train
# %mkdir cats
# %mkdir dogs
# %mv cat.*.jpg cats/
# %mv dog.*.jpg dogs/
#when done there should be zero files left in train 
DIR = DATA_HOME_DIR+'sample/train/'
print "after move: # files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
DIR = DATA_HOME_DIR+'sample/train/cats/'
print "# files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
DIR = DATA_HOME_DIR+'sample/train/dogs/'
print "# files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
# Out:
# before move: # files in  /home/ubuntu/fastai/data/dogscats/sample/train/ 0
# /home/ubuntu/fastai/data/dogscats/sample/train
# mkdir: cannot create directory ‘cats’: File exists
# mkdir: cannot create directory ‘dogs’: File exists
# mv: cannot stat 'cat.*.jpg': No such file or directory
# mv: cannot stat 'dog.*.jpg': No such file or directory
# after move: # files in  /home/ubuntu/fastai/data/dogscats/sample/train/ 0
# # files in  /home/ubuntu/fastai/data/dogscats/sample/train/cats/ 98
# # files in  /home/ubuntu/fastai/data/dogscats/sample/train/dogs/ 102

# %%
DIR = DATA_HOME_DIR+'sample/valid/'
print "before move: # files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])

# %cd $DATA_HOME_DIR/sample/valid
# %mkdir cats
# %mkdir dogs
# %mv cat.*.jpg cats/
# %mv dog.*.jpg dogs/

#when done there should be zero files left in train 
DIR = DATA_HOME_DIR+'sample/valid/'
print "after move: # files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
DIR = DATA_HOME_DIR+'sample/valid/cats/'
print "# files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
DIR = DATA_HOME_DIR+'sample/valid/dogs/'
print "# files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
# Out:
# before move: # files in  /home/ubuntu/fastai/data/dogscats/sample/valid/ 50
# /home/ubuntu/fastai/data/dogscats/sample/valid
# after move: # files in  /home/ubuntu/fastai/data/dogscats/sample/valid/ 0
# # files in  /home/ubuntu/fastai/data/dogscats/sample/valid/cats/ 24
# # files in  /home/ubuntu/fastai/data/dogscats/sample/valid/dogs/ 26

# %%
DIR = DATA_HOME_DIR+'train/'
print "before move: # files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])

# %cd $DATA_HOME_DIR/train
# %mkdir cats
# %mkdir dogs
# %mv cat.*.jpg cats/
# %mv dog.*.jpg dogs/

#when done there should be zero files left in train 
DIR = DATA_HOME_DIR+'sample/train/'
print "after move: # files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
DIR = DATA_HOME_DIR+'sample/train/cats/'
print "# files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
DIR = DATA_HOME_DIR+'sample/train/dogs/'
print "# files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
# Out:
# before move: # files in  /home/ubuntu/fastai/data/dogscats/train/ 0
# /home/ubuntu/fastai/data/dogscats/train
# mkdir: cannot create directory ‘cats’: File exists
# mkdir: cannot create directory ‘dogs’: File exists
# mv: cannot stat 'cat.*.jpg': No such file or directory
# mv: cannot stat 'dog.*.jpg': No such file or directory
# after move: # files in  /home/ubuntu/fastai/data/dogscats/sample/train/ 0
# # files in  /home/ubuntu/fastai/data/dogscats/sample/train/cats/ 98
# # files in  /home/ubuntu/fastai/data/dogscats/sample/train/dogs/ 102

# %%
DIR = DATA_HOME_DIR+'test/'
print "before move: # files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
DIR = DATA_HOME_DIR+'test/unknown/'
print "before move: # files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])

# Create single 'unknown' class for test set
# %cd $DATA_HOME_DIR/test
# %mv *.jpg unknown/

#when done there should be zero files left in train 
DIR = DATA_HOME_DIR+'test/'
print "after move: # files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
DIR = DATA_HOME_DIR+'test/unknown/'
print "# files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])


#NB: need test files in subdir unknown so when loaded they are put in a class by the loader.
# Out:
#  before move: # files in  /home/ubuntu/fastai/data/dogscats/test/ 0
# before move: # files in  /home/ubuntu/fastai/data/dogscats/test/unknown/ 12500
# /home/ubuntu/fastai/data/dogscats/test
# mv: cannot stat '*.jpg': No such file or directory
# after move: # files in  /home/ubuntu/fastai/data/dogscats/test/ 0
# # files in  /home/ubuntu/fastai/data/dogscats/test/unknown/ 12500

# %% [markdown]
# ## Finetuning and Training

# %%
DATA_HOME_DIR
# Out:
# '/home/ubuntu/fastai/data/dogscats/'

# %%
# %cd $DATA_HOME_DIR

#Set path to sample/ path if desired
path = DATA_HOME_DIR                    #use this when all code tested and ready for longer run
#path = DATA_HOME_DIR + 'sample/'         #use this during development - smaller dataset
test_path = DATA_HOME_DIR + 'test/'      #We use all the test data
results_path=DATA_HOME_DIR + 'results/'  #results always in this directory.
train_path=path + 'train/'
valid_path=path + 'valid/'
print "path:", path
print "test_path:", test_path
print "results_path:", results_path
print "train_path:", train_path
print "valid_path:", valid_path
# Out:
# /home/ubuntu/fastai/data/dogscats
# path: /home/ubuntu/fastai/data/dogscats/
# test_path: /home/ubuntu/fastai/data/dogscats/test/
# results_path: /home/ubuntu/fastai/data/dogscats/results/
# train_path: /home/ubuntu/fastai/data/dogscats/train/
# valid_path: /home/ubuntu/fastai/data/dogscats/valid/

# %%
#import Vgg16 helper class
vgg = Vgg16()

# %%
print type(vgg)
# Out:
# <type 'instance'>

# %%
#Set constants. You can experiment with no_of_epochs to improve the model
batch_size=64
no_of_epochs=3

# %%
startTime= datetime.now()
#Finetune the model
batches = vgg.get_batches(train_path, batch_size=batch_size)
val_batches = vgg.get_batches(valid_path, batch_size=batch_size*2)
timeElapsed=datetime.now()-startTime
print('Time elpased (hh:mm:ss.ms) {}'.format(timeElapsed))
# Out:
# Found 23000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Time elpased (hh:mm:ss.ms) 0:00:00.592933

# %%
startTime= datetime.now()
vgg.finetune(batches)
timeElapsed=datetime.now()-startTime
print('Time elpased (hh:mm:ss.ms) {}'.format(timeElapsed))

#Not sure if we set this for all fits
vgg.model.optimizer.lr = 0.01
# Out:
# Time elpased (hh:mm:ss.ms) 0:00:00.039230

# %%
print "no_of_epochs:", no_of_epochs
print os.getcwd()
print "results_path:", results_path
DIR = results_path
print "# files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
# Out:
# no_of_epochs: 3
# /home/ubuntu/fastai/data/dogscats
# results_path: /home/ubuntu/fastai/data/dogscats/results/
# # files in  /home/ubuntu/fastai/data/dogscats/results/ 3

# %%
#Notice we are passing in the validation dataset to the fit() method
#For each epoch we test our model against the validation set
startTime= datetime.now()
latest_weights_filename = None
for epoch in range(no_of_epochs):
    print "Running epoch: %d" % epoch
    vgg.fit(batches, val_batches, nb_epoch=1)
    latest_weights_filename = 'ft%d.h5' % epoch
    vgg.model.save_weights(results_path+latest_weights_filename)
print "Completed %s fit operations" % no_of_epochs
timeElapsed=datetime.now()-startTime
print('Time elpased (hh:mm:ss.ms) {}'.format(timeElapsed))

#sample data takes approx 16s/epoch
# Out:
# Running epoch: 0
# Epoch 1/1
# 23000/23000 [==============================] - 470s - loss: 1.4155 - acc: 0.8767 - val_loss: 1.5663 - val_acc: 0.8860
# Running epoch: 1
# Epoch 1/1
# 23000/23000 [==============================] - 449s - loss: 1.5779 - acc: 0.8869 - val_loss: 1.3986 - val_acc: 0.8955
# Running epoch: 2
# Epoch 1/1
# 23000/23000 [==============================] - 449s - loss: 1.4772 - acc: 0.8954 - val_loss: 0.8845 - val_acc: 0.9335
# Completed 3 fit operations
# Time elpased (hh:mm:ss.ms) 0:23:04.780662

# %%
DIR = results_path
print "# files in ", DIR, len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
# Out:
# # files in  /home/ubuntu/fastai/data/dogscats/results/ 3

# %% [markdown]
# ## Generate Predictions

# %% [markdown]
# Let's use our new model to make predictions on the test dataset

# %%
print "test_path:", test_path
# Out:
# test_path: /home/ubuntu/fastai/data/dogscats/test/

# %%
startTime= datetime.now()
batches, preds = vgg.test(test_path, batch_size = batch_size*2)
timeElapsed=datetime.now()-startTime
print('Time elpased (hh:mm:ss.ms) {}'.format(timeElapsed))
# Out:
# Found 12500 images belonging to 1 classes.
# Time elpased (hh:mm:ss.ms) 0:03:41.187584

# %%
print "batches:", type(batches)
print "preds:", type(preds), preds.shape
# Out:
# batches: <class 'keras.preprocessing.image.DirectoryIterator'>
# preds: <type 'numpy.ndarray'> (12500, 2)

# %%
#For every image, vgg.test() generates two probabilities 
#based on how we've ordered the cats/dogs directories.
#It looks like column one is cats and column two is dogs
print preds[:5]

filenames = batches.filenames
print filenames[:5]
# Out:
# [[  1.0000e+00   0.0000e+00]
#  [  0.0000e+00   1.0000e+00]
#  [  0.0000e+00   1.0000e+00]
#  [  1.0000e+00   4.6422e-28]
#  [  1.0000e+00   0.0000e+00]]
# ['unknown/2957.jpg', 'unknown/11706.jpg', 'unknown/10629.jpg', 'unknown/9810.jpg', 'unknown/9834.jpg']

# %%
#You can verify the column ordering by viewing some images
from PIL import Image
print filenames[0]
Image.open(test_path + filenames[0])
# Out:
# unknown/2957.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x374 at 0x7F87B11A1B90>

# %%
print filenames[1]
Image.open(test_path + filenames[1])
# Out:
# unknown/11706.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=330x360 at 0x7F87B1519AD0>

# %%
print filenames[2]
Image.open(test_path + filenames[2])
# Out:
# unknown/10629.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=350x349 at 0x7F87B0A80E50>

# %%
for i in range(0,preds.shape[0]):
    if preds[i,0]<0.1:
        print "at i=", i, preds[i]
    #print i, preds[i], preds[i,0]
    if i >= 200: break
print "end"
# Out:
# at i= 1 [ 0.  1.]
# at i= 2 [ 0.  1.]
# at i= 5 [ 0.  1.]
# at i= 9 [ 0.  1.]
# at i= 10 [ 0.  1.]
# at i= 12 [ 0.  1.]
# at i= 13 [ 0.  1.]
# at i= 14 [ 0.  1.]
# at i= 15 [  5.8691e-08   1.0000e+00]
# at i= 16 [ 0.  1.]
# at i= 24 [ 0.  1.]
# at i= 25 [ 0.  1.]
# at i= 27 [ 0.  1.]
# at i= 30 [ 0.  1.]
# at i= 33 [ 0.  1.]
# at i= 34 [ 0.  1.]
# at i= 37 [  1.2005e-13   1.0000e+00]
# at i= 38 [  6.7770e-14   1.0000e+00]
# at i= 40 [ 0.  1.]
# at i= 41 [  9.0525e-31   1.0000e+00]
# at i= 42 [ 0.  1.]
# at i= 43 [  1.3962e-32   1.0000e+00]
# at i= 44 [ 0.  1.]
# at i= 46 [ 0.  1.]
# at i= 50 [ 0.  1.]
# at i= 52 [ 0.  1.]
# at i= 54 [ 0.  1.]
# at i= 55 [ 0.  1.]
# at i= 57 [ 0.  1.]
# at i= 58 [  1.9256e-13   1.0000e+00]
# at i= 59 [ 0.  1.]
# at i= 61 [  1.5481e-10   1.0000e+00]
# at i= 62 [ 0.  1.]
# at i= 63 [ 0.  1.]
# at i= 66 [ 0.  1.]
# at i= 68 [ 0.  1.]
# at i= 69 [  1.1155e-17   1.0000e+00]
# at i= 70 [ 0.  1.]
# at i= 72 [ 0.  1.]
# at i= 73 [ 0.0387  0.9613]
# at i= 74 [ 0.  1.]
# at i= 75 [  1.2375e-27   1.0000e+00]
# at i= 77 [ 0.  1.]
# at i= 80 [ 0.  1.]
# at i= 81 [ 0.  1.]
# at i= 82 [ 0.  1.]
# at i= 87 [ 0.  1.]
# at i= 88 [ 0.  1.]
# at i= 89 [ 0.  1.]
# at i= 90 [ 0.  1.]
# at i= 95 [ 0.  1.]
# at i= 96 [ 0.  1.]
# at i= 101 [  1.3048e-19   1.0000e+00]
# at i= 102 [ 0.  1.]
# at i= 104 [ 0.  1.]
# at i= 105 [ 0.  1.]
# at i= 106 [ 0.  1.]
# at i= 107 [ 0.  1.]
# at i= 113 [ 0.  1.]
# at i= 118 [ 0.  1.]
# at i= 124 [ 0.  1.]
# at i= 126 [  1.7532e-16   1.0000e+00]
# at i= 127 [ 0.  1.]
# at i= 128 [  3.4302e-10   1.0000e+00]
# at i= 133 [  3.2565e-07   1.0000e+00]
# at i= 134 [  1.7285e-21   1.0000e+00]
# at i= 137 [ 0.  1.]
# at i= 139 [ 0.  1.]
# at i= 140 [ 0.  1.]
# at i= 143 [ 0.  1.]
# at i= 144 [  3.0630e-38   1.0000e+00]
# at i= 147 [ 0.  1.]
# at i= 150 [ 0.  1.]
# at i= 151 [ 0.  1.]
# at i= 154 [  1.3225e-12   1.0000e+00]
# at i= 155 [  3.0998e-38   1.0000e+00]
# at i= 159 [ 0.  1.]
# at i= 161 [ 0.  1.]
# at i= 163 [ 0.  1.]
# at i= 167 [ 0.  1.]
# at i= 168 [ 0.  1.]
# at i= 169 [ 0.  1.]
# at i= 170 [ 0.  1.]
# at i= 174 [ 0.  1.]
# at i= 175 [ 0.  1.]
# at i= 176 [ 0.  1.]
# at i= 177 [ 0.  1.]
# at i= 178 [ 0.  1.]
# at i= 180 [ 0.  1.]
# at i= 185 [  1.1347e-19   1.0000e+00]
# at i= 188 [ 0.  1.]
# at i= 189 [ 0.  1.]
# at i= 191 [ 0.  1.]
# at i= 195 [ 0.  1.]
# at i= 198 [ 0.  1.]
# at i= 199 [ 0.  1.]
# end

# %%
#Save our test results arrays so we can use them again later
save_array(results_path + 'test_preds.dat', preds)
save_array(results_path + 'filenames.dat', filenames)

# %% [markdown]
# ## Validate Predictions

# %% [markdown]
# Keras' *fit()* function conveniently shows us the value of the loss function, and the accuracy, after every epoch ("*epoch*" refers to one full run through all training examples). The most important metrics for us to look at are for the validation set, since we want to check for over-fitting.
#
# - **Tip**: with our first model we should try to overfit before we start worrying about how to reduce over-fitting - there's no point even thinking about regularization, data augmentation, etc if you're still under-fitting! (We'll be looking at these techniques shortly).
#
# As well as looking at the overall metrics, it's also a good idea to look at examples of each of:
# 1. A few correct labels at random
# 2. A few incorrect labels at random
# 3. The most correct labels of each class (ie those with highest probability that are correct)
# 4. The most incorrect labels of each class (ie those with highest probability that are incorrect)
# 5. The most uncertain labels (ie those with probability closest to 0.5).

# %% [markdown]
# Let's see what we can learn from these examples. (In general, this is a particularly useful technique for debugging problems in the model. However, since this model is so simple, there may not be too much to learn at this stage.)
#
# Calculate predictions on validation set, so we can find correct and incorrect examples:

# %%
vgg.model.load_weights(results_path+latest_weights_filename)

# %%
print "valid_path:", valid_path
# Out:
# valid_path: /home/ubuntu/fastai/data/dogscats/valid/

# %%
val_batches, probs = vgg.test(valid_path, batch_size = batch_size)
# Out:
# Found 2000 images belonging to 2 classes.

# %%
filenames = val_batches.filenames
expected_labels = val_batches.classes #0 or 1

#Round our predictions to 0/1 to generate labels
our_predictions = probs[:,0]
our_labels = np.round(1-our_predictions)

# %%
from keras.preprocessing import image

#Helper function to plot images by index in the validation set 
#Plots is a helper function in utils.py
def plots_idx(idx, titles=None):
    plots([image.load_img(valid_path + filenames[i]) for i in idx], titles=titles)
    
#Number of images to view for each visualization task
n_view = 4

# %%
print type(our_labels), our_labels.shape
print type(expected_labels), expected_labels.shape
# Out:
# <type 'numpy.ndarray'> (2000,)
# <type 'numpy.ndarray'> (2000,)

# %%
#1. A few correct labels at random
correct = np.where(our_labels==expected_labels)[0]
print "Found %d correct labels" % len(correct)
idx = permutation(correct)[:n_view]
plots_idx(idx, our_predictions[idx])
# Out:
# Found 1849 correct labels

# %%
#2. A few incorrect labels at random
incorrect = np.where(our_labels!=expected_labels)[0]
print "Found %d incorrect labels" % len(incorrect)
idx = permutation(incorrect)[:n_view]
plots_idx(idx, our_predictions[idx])
# Out:
# Found 151 incorrect labels

# %%
#3a. The images we most confident were cats, and are actually cats
correct_cats = np.where((our_labels==0) & (our_labels==expected_labels))[0]
print "Found %d confident correct cats labels" % len(correct_cats)
if len(correct_cats)!=0:
    most_correct_cats = np.argsort(our_predictions[correct_cats])[::-1][:n_view]
    plots_idx(correct_cats[most_correct_cats], our_predictions[correct_cats][most_correct_cats])
else:
    print "zero confident cats. SOMETHING WRONG!!!"
# Out:
# Found 901 confident correct cats labels

# %%
#3b. The images we most confident were dogs, and are actually dogs
correct_dogs = np.where((our_labels==1) & (our_labels==expected_labels))[0]
print "Found %d confident correct dogs labels" % len(correct_dogs)
most_correct_dogs = np.argsort(our_predictions[correct_dogs])[:n_view]
plots_idx(correct_dogs[most_correct_dogs], our_predictions[correct_dogs][most_correct_dogs])
# Out:
# Found 948 confident correct dogs labels

# %%
#4a. The images we were most confident were cats, but are actually dogs
incorrect_cats = np.where((our_labels==0) & (our_labels!=expected_labels))[0]
print "Found %d incorrect cats" % len(incorrect_cats)
if len(incorrect_cats):
    most_incorrect_cats = np.argsort(our_predictions[incorrect_cats])[::-1][:n_view]
    plots_idx(incorrect_cats[most_incorrect_cats], our_predictions[incorrect_cats][most_incorrect_cats])
# Out:
# Found 76 incorrect cats

# %%
#4b. The images we were most confident were dogs, but are actually cats
incorrect_dogs = np.where((our_labels==1) & (our_labels!=expected_labels))[0]
print "Found %d incorrect dogs" % len(incorrect_dogs)
if len(incorrect_dogs):
    most_incorrect_dogs = np.argsort(our_predictions[incorrect_dogs])[:n_view]
    plots_idx(incorrect_dogs[most_incorrect_dogs], our_predictions[incorrect_dogs][most_incorrect_dogs])
# Out:
# Found 75 incorrect dogs

# %%
#5. The most uncertain labels (ie those with probability closest to 0.5).
most_uncertain = np.argsort(np.abs(our_predictions-0.5))
plots_idx(most_uncertain[:n_view], our_predictions[most_uncertain])

# %% [markdown]
# Perhaps the most common way to analyze the result of a classification model is to use a [confusion matrix](http://www.dataschool.io/simple-guide-to-confusion-matrix-terminology/). Scikit-learn has a convenient function we can use for this purpose:

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(expected_labels, our_labels)

# %% [markdown]
# We can just print out the confusion matrix, or we can show a graphical view (which is mainly useful for dependents with a larger number of categories).

# %%
plot_confusion_matrix(cm, val_batches.class_indices)
# Out:
# [[901  75]
#  [ 76 948]]

# %% [markdown]
# ## Submit Predictions to Kaggle!

# %% [markdown]
# Here's the format Kaggle requires for new submissions:
# ```
# imageId,isDog
# 1242, .3984
# 3947, .1000
# 4539, .9082
# 2345, .0000
# ```
#
# Kaggle wants the imageId followed by the probability of the image being a dog. Kaggle uses a metric called [Log Loss](http://wiki.fast.ai/index.php/Log_Loss) to evaluate your submission.

# %%
#Load our test predictions from file
preds = load_array(results_path + 'test_preds.dat')
filenames = load_array(results_path + 'filenames.dat')

# %%
#Grab the dog prediction column
isdog = preds[:,1]
print "Raw Predictions: " + str(isdog[:5])
print "Mid Predictions: " + str(isdog[(isdog < .6) & (isdog > .4)])
print "Edge Predictions: " + str(isdog[(isdog == 1) | (isdog == 0)])
# Out:
# Raw Predictions: [  0.0000e+00   1.0000e+00   1.0000e+00   4.6422e-28   0.0000e+00]
# Mid Predictions: [ 0.4443  0.4673  0.5555  0.5939  0.4459  0.5054  0.4546  0.4137  0.4275]
# Edge Predictions: [ 0.  1.  1. ...,  0.  1.  1.]

# %% [markdown]
# [Log Loss](http://wiki.fast.ai/index.php/Log_Loss) doesn't support probability values of 0 or 1--they are undefined (and we have many). Fortunately, Kaggle helps us by offsetting our 0s and 1s by a very small value. So if we upload our submission now we will have lots of .99999999 and .000000001 values. This seems good, right?
#
# Not so. There is an additional twist due to how log loss is calculated--log loss rewards predictions that are confident and correct (p=.9999,label=1), but it punishes predictions that are confident and wrong far more (p=.0001,label=1). See visualization below.

# %%
#Visualize Log Loss when True value = 1
#y-axis is log loss, x-axis is probabilty that label = 1
#As you can see Log Loss increases rapidly as we approach 0
#But increases slowly as our predicted probability gets closer to 1

#this keeps throwing error. find fix later.
'''
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import log_loss

x = [i*.0001 for i in range(1,10000)]
y = [log_loss([1],[[i*.0001,1-(i*.0001)]],eps=1e-15) for i in range(1,10000,1)]

plt.plot(x, y)
plt.axis([-.05, 1.1, -.8, 10])
plt.title("Log Loss when true label = 1")
plt.xlabel("predicted probability")
plt.ylabel("log loss")

plt.show()
'''
# Out:
# '\nimport matplotlib.pyplot as plt\nimport numpy as np\nfrom sklearn.metrics import log_loss\n\nx = [i*.0001 for i in range(1,10000)]\ny = [log_loss([1],[[i*.0001,1-(i*.0001)]],eps=1e-15) for i in range(1,10000,1)]\n\nplt.plot(x, y)\nplt.axis([-.05, 1.1, -.8, 10])\nplt.title("Log Loss when true label = 1")\nplt.xlabel("predicted probability")\nplt.ylabel("log loss")\n\nplt.show()\n'

# %%
#So to play it safe, we use a sneaky trick to round down our edge predictions
#Swap all ones with .95 and all zeros with .05
isdog = isdog.clip(min=0.05, max=0.95)

# %%
#Extract imageIds from the filenames in our test/unknown directory 
filenames = batches.filenames
ids = np.array([int(f[8:f.find('.')]) for f in filenames])

# %% [markdown]
# Here we join the two columns into an array of [imageId, isDog]

# %%
subm = np.stack([ids,isdog], axis=1)
subm[:5]
# Out:
# array([[  2.9570e+03,   5.0000e-02],
#        [  1.1706e+04,   9.5000e-01],
#        [  1.0629e+04,   9.5000e-01],
#        [  9.8100e+03,   5.0000e-02],
#        [  9.8340e+03,   5.0000e-02]])

# %%
# %cd $DATA_HOME_DIR
submission_file_name = 'submission1.csv'
np.savetxt(submission_file_name, subm, fmt='%d,%.5f', header='id,label', comments='')
# Out:
# /home/ubuntu/fastai/data/dogscats

# %%
DATA_HOME_DIR
# Out:
# '/home/ubuntu/fastai/data/dogscats/'

# %%
from IPython.display import FileLink
#%cd $LESSON_HOME_DIR
#FileLink('data/redux/'+submission_file_name)
FileLink(submission_file_name)
# Out:
# /home/ubuntu/fastai/data/dogscats/submission1.csv

# %% [markdown]
# You can download this file and submit on the Kaggle website or use the Kaggle command line tool's "submit" method.

# %%
#kg submit <submission-file> -u <username> -p <password> -c <competition> -m "<message>"
#submitted 20-11-2017 score 0.10853 position ~ 534 out of ~1350 not great result.
